# %% [markdown]
# ## Transient Simulations
# *For simplicity, we will consider a year to be comprised of 12 30-day months.

# %% [markdown]
# ## 1. Import packages

# %%
#import packages
import flopy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mp
import pandas as pd
import numpy as np
import os
import time
import csv
import seaborn as sns
from pyDOE import *
import random
#additional analysis tools
import flopy.utils.binaryfile as bf
from flopy.utils.sfroutputfile import SfrFile

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
np.set_printoptions(threshold=np.inf)


moddir="C:/WRDAPP/MF2005.1_12/bin/mf2005.exe"
modws ="C:/Users/davem/Documents/Thesis/modflow/mfoutput"
modws= "D:/mfoutput/transientSeasons"


#jupyter specific--included to show plots in notebook
# %matplotlib inline

# %% [markdown]
# ## 2. Discretization and other inputs

# %%
# Discretization
nrow = 50 #number of rows
ncol = 50 #number of columns
nlay = 3  #number of layers

width = 100
dx= width #width of grid cells in x direction 
dy= width #width of grid cells in y direction 
Lx = ncol*dx  #width of domain in x
Ly = nrow*dy #width of domain in y

#ztop = 100
ztop = np.genfromtxt('base_model_elevs.csv', delimiter=',', dtype=float)   # top elevation of top layer (import from csv file) (dim: nrow,ncol)

## Subsurface properties - These get overwritten in the run code cell
#K_horiz = 1.    #horizontal hydraulic conductivity 
#K_vert = 1.    #assign vertical hydraulic conductivity (along z axis)
n = 0.1        #assign porosity
Ss = 0.0001      #assign storage coefficient
Sy = 0.1        #assign specific yield
uncnf = 1       #0=confined, >0 = unconfined

## ET
ET = 1e-5 #m/day
ET_locxy=[[24000,0], [0, 0]] #lower left and upper right corners of ET in xy coordinate
rip_ET= 10e-5  #riparian zone
rip_locxy= [[0,21000],[23000,0]]
extinction_depth = 10 #m

ET_rows_forced=(1.0, 49.0) #me forcing the et_rows to be 0-50
ET_cols_forced = (25.0, 49.0)

ET_zone = np.zeros((1,nrow,ncol))     # define an array of zeroes the size of the model grid
ET_zone[0,int(ET_rows_forced[0]):int(ET_rows_forced[1]), int(ET_cols_forced[0]):int(ET_cols_forced[1])] = ET 


rip_rows_forced = (22.0, 29.0)  #forced riparian area
rip_cols_forced = (1.0, 49.0)

ET_zone[0,int(rip_rows_forced[0]):int(rip_rows_forced[1]), int(rip_cols_forced[0]):int(rip_cols_forced[1])] = rip_ET 

Rip_zone = np.zeros((1,nrow,ncol))     # define an array of zeroes the size of the model grid
Rip_zone[0,int(rip_rows_forced[0]):int(rip_rows_forced[1]), int(rip_cols_forced[0]):int(rip_cols_forced[1])] = rip_ET 

## Recharge
rech=5e-5  #m/d


rech_rows_forced = (1.0, 49.0) #rech zone forced for leftmost 15 cols
rech_cols_forced = (1.0, 10.0)

rech_zone_forced = np.zeros((1,nrow,ncol))
rech_zone_forced[0,int(rech_rows_forced[0]):int(rech_rows_forced[1]),int(rech_cols_forced[0]):int(rech_cols_forced[1])]=rech


print(ztop[25])
# Out:
# [100.   99.   98.   97.   96.   95.   94.   93.   92.   91.   90.   89.
#   88.   87.   86.   85.   84.   83.   82.   81.   80.   79.   78.   77.
#   76.   75.9  75.8  75.7  75.6  75.5  75.4  75.3  75.2  75.1  75.   74.9
#   74.8  74.7  74.6  74.5  74.4  74.3  74.2  74.1  74.   73.9  73.8  73.7
#   73.6  73.5]

# %%
sp_peryr = 2   #number of seasons (with and wihtout ET. April-Sept and Oct-Mar)
sp1_len = 180  #sp lengths
sp2_len = 180
sim_years = 20
nper = int(sp_peryr*sim_years + 1)

#setup the steady state array
steady = np.ones(nper, dtype=bool)*False     # steady-state or transient flag for each stress period (boolean array)
#print(steady)
steady[0] = True    # initial stress period is steady-state

#make an array of period lengths
perlen=np.tile([sp1_len, sp2_len],sim_years)
perlen=np.append(10,perlen) #add a period of length 10 at the start for the steady state simulation
print("Period lengths", perlen)

#make an nstp array for the # of time steps to solve within each period in this case we will do daily 
#so we can repeat the perlen array - actually we are doing it every 6 days to save computation time
nstp=perlen/6 # Silghtly less than weekly 
nstp[0]=1 #for the steady state solution we just want one output
nstp = nstp.astype(int)
print("Number of Steps", nstp)

#Irrigation well

#Aqua Seca Well well
pumping = -1000 #m3/day 
SteadyPump = -250 #might want to increase the seasonal pumping
well_row =   19 #12
well_col =   32 #14
well_loc = (2,well_row, well_col)
well = [2,well_row, well_col, pumping] 


well_val = np.tile([1,0],sim_years)
well_val = np.append(0,well_val)
wel_spd =  {1: [2,well_row, well_col, 0]}
#ET_val=np.tile([1, 0],sim_years)
#ET_val=np.append(sampling[i][4]/2,ET_val) #add on steady state period at beginning with 1/2 the ET 
for p in range(0, nper):   
    #pumping = 0
    wel_spd[p+1] =  [2,well_row, well_col, pumping*well_val[p]]

# #Steady Pumping rate Transient
# wel_spdst =  {0: [2,well_row, well_col, 0]}
# well_val = np.tile([1,1],sim_years+1)
# for p in range(1, nper):   
#     #pumping = 0
#     wel_spdst[p] =  [2,well_row, well_col, SteadyPump*well_val[p]]
    
print(wel_spd)
# Out:
# Period lengths [ 10 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180
#  180 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180 180
#  180 180 180 180 180]
# Number of Steps [ 1 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30
#  30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30 30]
# {1: [2, 19, 32, 0], 2: [2, 19, 32, -1000], 3: [2, 19, 32, 0], 4: [2, 19, 32, -1000], 5: [2, 19, 32, 0], 6: [2, 19, 32, -1000], 7: [2, 19, 32, 0], 8: [2, 19, 32, -1000], 9: [2, 19, 32, 0], 10: [2, 19, 32, -1000], 11: [2, 19, 32, 0], 12: [2, 19, 32, -1000], 13: [2, 19, 32, 0], 14: [2, 19, 32, -1000], 15: [2, 19, 32, 0], 16: [2, 19, 32, -1000], 17: [2, 19, 32, 0], 18: [2, 19, 32, -1000], 19: [2, 19, 32, 0], 20: [2, 19, 32, -1000], 21: [2, 19, 32, 0], 22: [2, 19, 32, -1000], 23: [2, 19, 32, 0], 24: [2, 19, 32, -1000], 25: [2, 19, 32, 0], 26: [2, 19, 32, -1000], 27: [2, 19, 32, 0], 28: [2, 19, 32, -1000], 29: [2, 19, 32, 0], 30: [2, 19, 32, -1000], 31: [2, 19, 32, 0], 32: [2, 19, 32, -1000], 33: [2, 19, 32, 0], 34: [2, 19, 32, -1000], 35: [2, 19, 32, 0], 36: [2, 19, 32, -1000], 37: [2, 19, 32, 0], 38: [2, 19, 32, -1000], 39: [2, 19, 32, 0], 40: [2, 19, 32, -1000], 41: [2, 19, 32, 0]}

# %% [markdown]
# ### Layering

# %%
## define layer properties 
K_horiz = 10 #m/d
K_vert = 10 #m/d
K_vert2 = 0.0001 #m/d  #K for the middle layer 


## make horizontal K np arrays
Kh = np.zeros((nlay,nrow,ncol))     # define an array of zeros the size of the model grid (nlay, nrow, ncol)
Kh[:,:,:] = K_horiz # assign the original value to the entire array

## Make a arrays for the K values
Kz = np.zeros((nlay,nrow,ncol))     # define an array of zeros the size of the model grid (nlay, nrow, ncol)
Kz[:,:,:] = K_vert                   # assign the original value to the entire array

## Made some changes to the thickness
bot_elev = 0. #0
mid_elev = 40. #40
top_elev = 45. #45

botm = np.zeros((nlay,nrow,ncol)) # initialize array of zeros for bottom elevation for each model cell (dim: nlay,nrow,ncol)
botm[2,:,:] = bot_elev                 # bottom elevation of lowest layer (2) is 0 m
botm[1,:,:] = mid_elev                 #bottom elevation of middle layer (1) is 40 m           
botm[0,:,:] = top_elev                 # bottom elevation of top layer (0) 45

# %% [markdown]
# ## Boundary Conditions

# %%
#original BCS

#print(ibound)
#setup initial heads as 1 everywhere except on the boundaries
H_init = np.ones((nlay, nrow, ncol), dtype=np.float32)  #float array (i.e. decimal), sets all heads to 1.0

## Right Boundary condition
h_right = 62 #was 70

H_init[:, :, :] = h_right  #initialize the entire domain to the right head value
H_init[:, :, 49] = h_right    #replace first (right) col with desired head value

#########################
#Define cell activity (IBOUND)
ibound=np.ones((nlay,nrow,ncol))                                                  
ibound[:,:,0] = 0  #1st col = no flow       
ibound[:,:,49] = -1  #last col = constant head 

ibound[:,0,:49]=0
ibound[:,49,:49]=0
ibound[:,0,49]=0
ibound[:,49,49]=0
ibound[:,1,:5]=0
ibound[:,2,:4]=0
ibound[:,3,:3]=0
ibound[:,4,:2]=0

ibound[:,48,:5]=0
ibound[:,47,:4]=0
ibound[:,46,:3]=0
ibound[:,45,:2]=0

ibound[1:,1,:7]=0
ibound[1:,2,:6]=0
ibound[1:,3,:5]=0
ibound[1:,4,:4]=0
ibound[1:,5,:3]=0
ibound[1:,6,1]=0

ibound[1:,48,:7]=0
ibound[1:,47,:6]=0
ibound[1:,46,:5]=0
ibound[1:,45,:4]=0
ibound[1:,44,:3]=0
ibound[1:,43,1]=0

ibound[2,1,:9]=0
ibound[2,2,:8]=0
ibound[2,3,:7]=0
ibound[2,4,:6]=0
ibound[2,5,:5]=0
ibound[2,6,:4]=0
ibound[2,7,:3]=0
ibound[2,8,1]=0

ibound[2,48,:9]=0
ibound[2,47,:8]=0
ibound[2,46,:7]=0
ibound[2,45,:6]=0
ibound[2,44,:5]=0
ibound[2,43,:4]=0
ibound[2,42,:3]=0
ibound[2,41,1]=0

#new bottom no flow zone constriction
ibound[:,1,19:]=0
ibound[:,2,25:]=0
ibound[:,3,30:]=0
ibound[:,4,33:]=0
ibound[:,5,36:]=0
ibound[:,6,39:]=0
ibound[:,7,41:]=0
ibound[:,8,43:]=0
ibound[:,9,45:]=0
ibound[:,10,46:]=0
ibound[:,11,47:]=0
ibound[:,12,48:]=0

ibound[:,48,19:]=0
ibound[:,47,25:]=0
ibound[:,46,30:]=0
ibound[:,45,33:]=0
ibound[:,44,36:]=0
ibound[:,43,39:]=0
ibound[:,42,41:]=0
ibound[:,41,43:]=0
ibound[:,40,45:]=0
ibound[:,39,46:]=0
ibound[:,38,47:]=0
ibound[:,37,48:]=0

#np.savetxt("ibound_lyr1.txt", ibound[0])

# %% [markdown]
# ## Stream with SFR2 Package

# %%
#SFR package inputs

reach = np.recarray((nrow,), dtype=[('k', '<f8'), ('i', '<f8'), ('j', '<f8'), ('iseg', '<f8'), ('ireach', '<f8'), ('rchlen', '<f8'),('strtop', '<f4')])

reach[:][:] = 0.0 # zero it out
#reach['k'][:] = 0 #testing
reach['i'][:] = ncol/2   #set it to the middle row
reach['j'][:] = [i for i in range(nrow)] #all columns in the middle row
reach['iseg'][:] = 1 #segment number - we only have 1 so all cells - segment number starts with 1!
#reach['iseg'][25:] = 2
reach['ireach'][:50] = [i for i in range(1,51)] #number the 50 reaches - starts with 1!
#reach['ireach'][25:] = [i for i in range(1,26)]
reach['rchlen'][:] = dx
reach['strtop'][:] = ztop[25]-5 #Sets the stream elevation to below the top of the top layer cells 
#print(ztop)

#Segment Data
dtype = flopy.modflow.ModflowSfr2.get_default_segment_dtype() #get the correct datatypes for the segments
indices = ['nseg','width1','width2','icalc','roughch','flow','outseg','iupseg','hcond1','hcond2','thickm1','thickm2','etsw','pptsw','elevup','elevdn']

seg_data = np.recarray((1,), dtype[indices])
seg_data[:] = 0
seg_data['width1'] = 5 #Upstream width
seg_data['width2'] = 10 #downstream width
seg_data['icalc'] = 1 #Stream depth calculated every stress period - assumes wide rectangular channel - uses Manning's equation
seg_data['nseg'] = 1 #segment number
seg_data['roughch'] = 0.035 #Manning's n 
seg_data['flow'] = 1 #initial inflow at first reach in segment
seg_data['hcond1'] = 0.0001 #K - also set in the run cell as it is one of the parameters that is varied
seg_data['hcond2'] = 0.0001 
seg_data['thickm1'] = 2  #Stream bed thickness
seg_data['thickm2'] = 2  
seg_data['elevup'] = reach['strtop'][0]   #elevation at start added reach strtop for transeint was 100 and 70 for eleveldn
seg_data['elevdn'] = reach['strtop'][-1]
seg_data['etsw'] = 0  #Stream channel ET
seg_data['pptsw'] = 0 #Stream channel precip

segment_data = seg_data

nstrm = -len(reach)  # number of reaches - negative for transient!
nss = 1 #len(seg_data[0])  # number of segments
nsfrpar = 0  # number of parameters (not supported)
nparseg = 0
const = 1.0  # constant for manning's equation, units of cfs
dleak = 0.01  # closure tolerance for stream stage computation
ipakcb = 53  # flag for writing SFR output to cell-by-cell budget (on unit 53)
istcb2 = 81  # flag for writing SFR output to text file

dataset_5 = {0:[nss, 0, 0]}  # dataset 5 (see online guide) - first one must be equal to number of segments 

for i in range(1,nper):
    dataset_5[i] = [0, 0, 0] #one for every stress period, first number must be less than number of segments (except first stress period) (for some reason)


irtflg = 1 #flag for routng with kinematic wave, if so desired, uses defaults for other routing params

# %%
##Only going to use the simulations that worked for the Drawdown Situation to save space and time computing

error_list = np.loadtxt('ErrorSteadyPump_Sfr750Test.txt')
sampling = np.loadtxt("ModflowParams7-750Test12.txt")
n = np.arange(0,len(sampling))

#print(error_list[:,0])
n2 = np.setdiff1d(n, error_list[:,0].astype('int'))
#print(len(n2))
#print(n2)

# %% [markdown]
# ## create packages and run model

# %%
#create model object

#load in the parameter sampling from text - so it's the same everytime
#sampling = np.loadtxt("ModflowParams7-750Test12.txt")
#n = len(sampling)#np.loadtxt('TransSamples.txt').astype('int')
error_list = []

#using list of working simulations from drawdown - n2 in previous code block 
for i in n2:
    t0 = time.time()
    #print(sampling[i])
    #modelname = "ScenarioSfr750Seasons_"+str(i)
    modelname = "ScenarioSfr750SeasonsTest_"+str(i)
    m = flopy.modflow.Modflow(modelname,model_ws = modws, exe_name = moddir)

    #Discretization - dis
    dis = flopy.modflow.ModflowDis(model=m, nlay=nlay, nrow=nrow, ncol=ncol, 
                               delr=dx, delc=dy, top=ztop, botm=botm, 
                               itmuni = 4, lenuni = 2, 
                               nper=nper, steady=steady,perlen=perlen, nstp=nstp)

    # Boundary and initial conditions - bas
    bas = flopy.modflow.ModflowBas(m, ibound=ibound, strt=H_init)

    #Layer properties - lpf
    ## make horizontal K np arrays
    #Kh = np.zeros((nlay,nrow,ncol))     # define an array of zeros the size of the model grid (nlay, nrow, ncol)
    Kh[:,:,:] = sampling[i][0] # assign the original value to the entire array

    ## Make a arrays for the K values
    #Kz = np.zeros((nlay,nrow,ncol))     # define an array of zeros the size of the model grid (nlay, nrow, ncol)
    Kz[:,:,:] = sampling[i][0] #* sampling[i][7]                # assign the original value to the entire array
    
    #restrictive layer
    Kz[1,:,10:49] = sampling[i][0] * sampling[i][1] #* sampling[i][7]       #Replace K in the middle layer with the lower value
    Kh[1,:,10:49] = sampling[i][0] * sampling[i][1]     
    #changed to 10 for start of restrictive layer
    
    Sy = sampling[i][2]
    
    lpf = flopy.modflow.ModflowLpf(m, laytyp=1, hk=Kh, #laywet = [1,1,1],
                               vka=Kz, ss=Ss,
                               sy=Sy,storagecoefficient=True, ipakcb=53)
    
    #Setting up ET stress periods   
    ET_zone[0,int(ET_rows_forced[0]):int(ET_rows_forced[1]), int(ET_cols_forced[0]):int(ET_cols_forced[1])] = sampling[i][4]
    ET_zone[0,int(rip_rows_forced[0]):int(rip_rows_forced[1]), int(rip_cols_forced[0]):int(rip_cols_forced[1])] = (sampling[i][4] * sampling[i][5])
    
    ET_val=np.tile([1, 0],sim_years)
    ET_val=np.append(1/2,ET_val) #add on steady state period at beginning with 1/2 the ET 
    
    ET = {} #ET Stress period dictionary
    for p in range(0,nper):    #loop over stress periods
        #print(ET_val[p])        
        ET[p+1]=ET_zone*ET_val[p] 
    
    evt = flopy.modflow.mfevt.ModflowEvt(m, surf=ztop, evtr=ET, exdp=extinction_depth, ipakcb=53)
    #evt = flopy.modflow.mfevt.ModflowEvt(m, surf=ztop, evtr=ET_zone, exdp=extinction_depth, ipakcb=53) #no seasonality


    #Recharge - rch
    rech_zone_forced[0,int(rech_rows_forced[0]):int(rech_rows_forced[1]),int(rech_cols_forced[0]):int(rech_cols_forced[1])]=sampling[i][3]
      
    rch = flopy.modflow.mfrch.ModflowRch(model=m, nrchop=3, rech=rech_zone_forced, ipakcb=53)     #create rch object

    #SFR2 
    seg_data['hcond1'] = seg_data['hcond2'] = sampling[i][6]
    
    sfr = flopy.modflow.ModflowSfr2(
        model = m,
        nstrm=nstrm,
        nss=nss,
        const=const,
        dleak=dleak,
        ipakcb=ipakcb,
        #istcb1 = 81,
        istcb2=istcb2,
        reach_data=reach,
        segment_data=seg_data,
        #channel_geometry_data=channel_geometry_data,
        #channel_flow_data=channel_flow_data,
        dataset_5=dataset_5,
        #unit_number=15,
        irtflg = irtflg,
        numtim = 2,
        flwtol = 0.001,#number of timesteps to compute for routing
        transroute = True
    )
    sfr.assign_layers(adjust_botms=True, pad=1.0) #I haven't figure out yet why the Transient version has issues with the channel bottom - but this fixes it by offsetting by -1 if there is an issue
    #print(sfr.reach_data)
    
    #Well - wel
    wel = flopy.modflow.ModflowWel(model=m, stress_period_data=wel_spd) #Seasonal pumping
   # wel = flopy.modflow.ModflowWel(model=m, stress_period_data=wel_spdst) #steady pumping lower rate

    #Output control - OC 

    oc_spd = {}
    for kper in range(nper):
        for kstp in range(nstp[kper]):
            #print(kstp)
            oc_spd[(kper, kstp)] = ['save head','save drawdown','save budget','print head','print budget']
   # spd = {(-1, -1): [],
     #   (0,0):['print head', 'print budget', 'save head', 'save budget']} #create a dictionary for stress period data, where key (0,0) is associated with value ['print...'] 
    oc = flopy.modflow.ModflowOc(model=m, stress_period_data=oc_spd, compact=True)

    #Numerical solver - pcg
    pcg = flopy.modflow.ModflowPcg(model=m, 
                               mxiter=100, iter1=200, 
                               relax = 0.97,
                               damp = 0.7
                              )
    #chk = sfr.check()
#     wel.check()
#     pcg.check()
#     m.check()
#     oc.check()
#     evt.check()
#     rch.check()
#     lpf.check()
#     bas.check()
    #write the inputs
    #sfr.plot(key='iseg')
    m.write_input()   
    
    #Run the model 
    success, mfoutput = m.run_model(pause=False, report=False, silent=True)
    
    t1 = time.time()
    tt = t1-t0
    if not success:
        #raise Exception('MODFLOW did not terminate normally.')      
        print('MODFLOW did not terminate normally. Parameters saved to file. Time: ' + str(tt))
        #save parameters        
        error_list.append(np.hstack((np.array(i),sampling[i])))
        #leakage_array[i] = -1
    else:
        print("Simulation " + str(i) + " Terminated Normally. Time: " + str(tt))
#         #older format that saves the output at the end stream reach cell for easier use in the Decision Tree 
#         #now I just grab all the data seperately in the Tree Notebook
#         sfrout = SfrFile(modws+'/'+ modelname+'.sfr.out') 
#         df = sfrout.get_dataframe()
#         leakage_array[i] = df.Qout[49]

if error_list:
    #np.savetxt("ErrorSeasons_Sfr750.txt", error_list)
    np.savetxt("ErrorSeasons_Sfr750Test.txt", error_list)

    print(len(error_list), " simulations did not terminate normally.")
# Out:
# Simulation 1 Terminated Normally. Time: 98.1353051662445
# Simulation 2 Terminated Normally. Time: 114.0017499923706
# Simulation 3 Terminated Normally. Time: 92.82476496696472
# Simulation 4 Terminated Normally. Time: 78.30565547943115
# Simulation 6 Terminated Normally. Time: 146.13541388511658
# Simulation 7 Terminated Normally. Time: 99.02372455596924
# Simulation 8 Terminated Normally. Time: 83.31946778297424
# Simulation 9 Terminated Normally. Time: 164.02080273628235
# Simulation 10 Terminated Normally. Time: 103.32131028175354
# Simulation 11 Terminated Normally. Time: 134.02917790412903
# MODFLOW did not terminate normally. Parameters saved to file. Time: 100.02710103988647
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.3909900188446045
# Simulation 14 Terminated Normally. Time: 139.61762928962708
# Simulation 15 Terminated Normally. Time: 96.3069577217102
# Simulation 16 Terminated Normally. Time: 86.36743354797363
# MODFLOW did not terminate normally. Parameters saved to file. Time: 72.25442099571228
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.7036023139953613
# MODFLOW did not terminate normally. Parameters saved to file. Time: 88.9336462020874
# Simulation 20 Terminated Normally. Time: 134.5097734928131
# Simulation 21 Terminated Normally. Time: 137.7287082672119
# Simulation 22 Terminated Normally. Time: 76.43871974945068
# Simulation 23 Terminated Normally. Time: 122.79052972793579
# Simulation 26 Terminated Normally. Time: 103.28330206871033
# Simulation 27 Terminated Normally. Time: 91.44462084770203
# Simulation 28 Terminated Normally. Time: 80.97642683982849
# Simulation 30 Terminated Normally. Time: 93.01305508613586
# Simulation 31 Terminated Normally. Time: 94.80320286750793
# Simulation 35 Terminated Normally. Time: 104.71800303459167
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.391878128051758
# Simulation 38 Terminated Normally. Time: 79.03149700164795
# Simulation 39 Terminated Normally. Time: 89.72825264930725
# Simulation 40 Terminated Normally. Time: 154.35538268089294
# Simulation 45 Terminated Normally. Time: 123.15580725669861
# Simulation 46 Terminated Normally. Time: 105.5041151046753
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.631801128387451
# Simulation 48 Terminated Normally. Time: 76.30005931854248
# Simulation 49 Terminated Normally. Time: 81.32913446426392
# Simulation 50 Terminated Normally. Time: 154.97512578964233
# Simulation 51 Terminated Normally. Time: 97.66778469085693
# Simulation 52 Terminated Normally. Time: 93.28209257125854
# Simulation 53 Terminated Normally. Time: 96.89357209205627
# Simulation 55 Terminated Normally. Time: 118.68258881568909
# Simulation 56 Terminated Normally. Time: 77.74338483810425
# MODFLOW did not terminate normally. Parameters saved to file. Time: 24.78270435333252
# Simulation 58 Terminated Normally. Time: 97.18198347091675
# Simulation 59 Terminated Normally. Time: 80.02788972854614
# Simulation 62 Terminated Normally. Time: 89.7261712551117
# MODFLOW did not terminate normally. Parameters saved to file. Time: 59.352322816848755
# Simulation 64 Terminated Normally. Time: 85.40470933914185
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.2533438205718994
# Simulation 67 Terminated Normally. Time: 141.56300520896912
# MODFLOW did not terminate normally. Parameters saved to file. Time: 33.99001598358154
# Simulation 69 Terminated Normally. Time: 73.9014744758606
# Simulation 70 Terminated Normally. Time: 137.19567346572876
# Simulation 72 Terminated Normally. Time: 96.2693178653717
# Simulation 74 Terminated Normally. Time: 125.44810771942139
# Simulation 75 Terminated Normally. Time: 135.6801266670227
# Simulation 76 Terminated Normally. Time: 151.09574937820435
# Simulation 77 Terminated Normally. Time: 90.19108200073242
# Simulation 78 Terminated Normally. Time: 104.63961625099182
# Simulation 79 Terminated Normally. Time: 113.13803362846375
# Simulation 80 Terminated Normally. Time: 93.57613062858582
# MODFLOW did not terminate normally. Parameters saved to file. Time: 37.61160445213318
# Simulation 82 Terminated Normally. Time: 110.98738598823547
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.3385190963745117
# Simulation 86 Terminated Normally. Time: 133.77654099464417
# MODFLOW did not terminate normally. Parameters saved to file. Time: 113.91149735450745
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.5282344818115234
# Simulation 89 Terminated Normally. Time: 97.94037675857544
# Simulation 90 Terminated Normally. Time: 92.54164910316467
# Simulation 91 Terminated Normally. Time: 105.57006478309631
# MODFLOW did not terminate normally. Parameters saved to file. Time: 90.46429491043091
# Simulation 93 Terminated Normally. Time: 118.5007152557373
# Simulation 94 Terminated Normally. Time: 96.5385069847107
# Simulation 95 Terminated Normally. Time: 78.65278053283691
# Simulation 96 Terminated Normally. Time: 99.75596213340759
# Simulation 97 Terminated Normally. Time: 127.85368323326111
# Simulation 98 Terminated Normally. Time: 90.35970163345337
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.765122413635254
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.9674713611602783
# Simulation 104 Terminated Normally. Time: 88.44920468330383
# Simulation 105 Terminated Normally. Time: 107.74149346351624
# Simulation 106 Terminated Normally. Time: 106.80430579185486
# Simulation 107 Terminated Normally. Time: 102.80325102806091
# MODFLOW did not terminate normally. Parameters saved to file. Time: 27.284626483917236
# MODFLOW did not terminate normally. Parameters saved to file. Time: 88.92854356765747
# Simulation 111 Terminated Normally. Time: 146.90442204475403
# MODFLOW did not terminate normally. Parameters saved to file. Time: 30.02811884880066
# MODFLOW did not terminate normally. Parameters saved to file. Time: 112.45754766464233
# Simulation 114 Terminated Normally. Time: 86.08435797691345
# Simulation 115 Terminated Normally. Time: 118.48762512207031
# MODFLOW did not terminate normally. Parameters saved to file. Time: 7.957674741744995
# MODFLOW did not terminate normally. Parameters saved to file. Time: 154.76269793510437
# MODFLOW did not terminate normally. Parameters saved to file. Time: 17.975971221923828
# MODFLOW did not terminate normally. Parameters saved to file. Time: 33.19749164581299
# MODFLOW did not terminate normally. Parameters saved to file. Time: 112.15071678161621
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.857672691345215
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.243516683578491
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.5109353065490723
# Simulation 130 Terminated Normally. Time: 80.69181942939758
# Simulation 131 Terminated Normally. Time: 132.1349663734436
# Simulation 132 Terminated Normally. Time: 82.27101612091064
# Simulation 133 Terminated Normally. Time: 90.64977765083313
# Simulation 134 Terminated Normally. Time: 119.72204089164734
# Simulation 135 Terminated Normally. Time: 129.62076568603516
# MODFLOW did not terminate normally. Parameters saved to file. Time: 26.723910093307495
# Simulation 137 Terminated Normally. Time: 92.2387318611145
# Simulation 138 Terminated Normally. Time: 82.74697518348694
# Simulation 139 Terminated Normally. Time: 81.52058506011963
# MODFLOW did not terminate normally. Parameters saved to file. Time: 89.66691899299622
# Simulation 143 Terminated Normally. Time: 101.50772643089294
# Simulation 145 Terminated Normally. Time: 70.62044620513916
# Simulation 148 Terminated Normally. Time: 112.2345016002655
# Simulation 149 Terminated Normally. Time: 99.60344386100769
# MODFLOW did not terminate normally. Parameters saved to file. Time: 1.9964196681976318
# Simulation 153 Terminated Normally. Time: 80.71856713294983
# MODFLOW did not terminate normally. Parameters saved to file. Time: 43.67117404937744
# Simulation 156 Terminated Normally. Time: 127.59756660461426
# Simulation 157 Terminated Normally. Time: 104.74927353858948
# Simulation 158 Terminated Normally. Time: 137.01972460746765
# Simulation 159 Terminated Normally. Time: 89.24703097343445
# Simulation 161 Terminated Normally. Time: 141.08052492141724
# Simulation 162 Terminated Normally. Time: 87.52603340148926
# Simulation 163 Terminated Normally. Time: 139.56247878074646
# Simulation 164 Terminated Normally. Time: 97.69742488861084
# Simulation 165 Terminated Normally. Time: 105.28136444091797
# MODFLOW did not terminate normally. Parameters saved to file. Time: 43.501301527023315
# Simulation 168 Terminated Normally. Time: 153.66327357292175
# Simulation 170 Terminated Normally. Time: 82.20930981636047
# MODFLOW did not terminate normally. Parameters saved to file. Time: 71.30967974662781
# Simulation 174 Terminated Normally. Time: 122.69353222846985
# Simulation 175 Terminated Normally. Time: 101.89441657066345
# Simulation 176 Terminated Normally. Time: 94.07844948768616
# Simulation 178 Terminated Normally. Time: 137.1628909111023
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.1087534427642822
# MODFLOW did not terminate normally. Parameters saved to file. Time: 14.176944255828857
# MODFLOW did not terminate normally. Parameters saved to file. Time: 74.4093906879425
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.341348886489868
# Simulation 184 Terminated Normally. Time: 140.54329252243042
# MODFLOW did not terminate normally. Parameters saved to file. Time: 53.981136322021484
# Simulation 186 Terminated Normally. Time: 145.00204348564148
# Simulation 187 Terminated Normally. Time: 97.00531196594238
# MODFLOW did not terminate normally. Parameters saved to file. Time: 53.56528830528259
# MODFLOW did not terminate normally. Parameters saved to file. Time: 91.58116340637207
# Simulation 191 Terminated Normally. Time: 116.55137062072754
# Simulation 192 Terminated Normally. Time: 108.9355034828186
# Simulation 193 Terminated Normally. Time: 109.8426342010498
# Simulation 194 Terminated Normally. Time: 77.3536741733551
# MODFLOW did not terminate normally. Parameters saved to file. Time: 11.338958024978638
# Simulation 196 Terminated Normally. Time: 89.76672983169556
# Simulation 197 Terminated Normally. Time: 90.91827154159546
# MODFLOW did not terminate normally. Parameters saved to file. Time: 118.61192679405212
# Simulation 199 Terminated Normally. Time: 77.5260078907013
# Simulation 200 Terminated Normally. Time: 122.70240116119385
# MODFLOW did not terminate normally. Parameters saved to file. Time: 12.637006282806396
# Simulation 202 Terminated Normally. Time: 93.57910895347595
# MODFLOW did not terminate normally. Parameters saved to file. Time: 117.44654655456543
# Simulation 204 Terminated Normally. Time: 138.23206233978271
# MODFLOW did not terminate normally. Parameters saved to file. Time: 67.94480514526367
# Simulation 206 Terminated Normally. Time: 123.14576530456543
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.701389789581299
# Simulation 208 Terminated Normally. Time: 153.93625116348267
# Simulation 209 Terminated Normally. Time: 123.03934049606323
# Simulation 210 Terminated Normally. Time: 84.5411581993103
# MODFLOW did not terminate normally. Parameters saved to file. Time: 80.22068548202515
# Simulation 212 Terminated Normally. Time: 89.03692078590393
# Simulation 213 Terminated Normally. Time: 117.79170513153076
# Simulation 214 Terminated Normally. Time: 113.53345108032227
# MODFLOW did not terminate normally. Parameters saved to file. Time: 70.61507272720337
# Simulation 216 Terminated Normally. Time: 88.9944064617157
# Simulation 218 Terminated Normally. Time: 94.39166927337646
# Simulation 221 Terminated Normally. Time: 86.31809425354004
# MODFLOW did not terminate normally. Parameters saved to file. Time: 121.17132806777954
# MODFLOW did not terminate normally. Parameters saved to file. Time: 32.53261661529541
# MODFLOW did not terminate normally. Parameters saved to file. Time: 41.91040229797363
# Simulation 226 Terminated Normally. Time: 148.22531533241272
# Simulation 227 Terminated Normally. Time: 140.62281894683838
# Simulation 228 Terminated Normally. Time: 86.58328533172607
# MODFLOW did not terminate normally. Parameters saved to file. Time: 8.041441202163696
# Simulation 234 Terminated Normally. Time: 97.73300838470459
# MODFLOW did not terminate normally. Parameters saved to file. Time: 95.4537045955658
# Simulation 237 Terminated Normally. Time: 101.7101137638092
# Simulation 238 Terminated Normally. Time: 93.85439872741699
# Simulation 240 Terminated Normally. Time: 108.97627902030945
# Simulation 241 Terminated Normally. Time: 102.80896258354187
# Simulation 242 Terminated Normally. Time: 79.60858106613159
# Simulation 243 Terminated Normally. Time: 108.1693663597107
# MODFLOW did not terminate normally. Parameters saved to file. Time: 38.378817319869995
# Simulation 246 Terminated Normally. Time: 143.72976541519165
# Simulation 247 Terminated Normally. Time: 92.12136363983154
# Simulation 248 Terminated Normally. Time: 170.0341911315918
# MODFLOW did not terminate normally. Parameters saved to file. Time: 63.87646126747131
# Simulation 251 Terminated Normally. Time: 160.75949788093567
# Simulation 252 Terminated Normally. Time: 130.44564628601074
# Simulation 253 Terminated Normally. Time: 132.61365127563477
# Simulation 256 Terminated Normally. Time: 119.20974564552307
# Simulation 257 Terminated Normally. Time: 79.23516416549683
# Simulation 258 Terminated Normally. Time: 93.83139681816101
# Simulation 259 Terminated Normally. Time: 109.66458296775818
# Simulation 261 Terminated Normally. Time: 81.23869299888611
# MODFLOW did not terminate normally. Parameters saved to file. Time: 78.016597032547
# MODFLOW did not terminate normally. Parameters saved to file. Time: 26.84346055984497
# Simulation 265 Terminated Normally. Time: 111.66400384902954
# MODFLOW did not terminate normally. Parameters saved to file. Time: 20.823013067245483
# Simulation 267 Terminated Normally. Time: 137.74895119667053
# Simulation 268 Terminated Normally. Time: 119.05451393127441
# MODFLOW did not terminate normally. Parameters saved to file. Time: 11.321537256240845
# Simulation 270 Terminated Normally. Time: 111.78734159469604
# MODFLOW did not terminate normally. Parameters saved to file. Time: 62.95781445503235
# MODFLOW did not terminate normally. Parameters saved to file. Time: 35.82007336616516
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.736569404602051
# Simulation 275 Terminated Normally. Time: 84.5794849395752
# Simulation 276 Terminated Normally. Time: 86.24286150932312
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.8990001678466797
# MODFLOW did not terminate normally. Parameters saved to file. Time: 53.87104320526123
# Simulation 280 Terminated Normally. Time: 84.00002193450928
# MODFLOW did not terminate normally. Parameters saved to file. Time: 30.740039110183716
# Simulation 282 Terminated Normally. Time: 143.55639028549194
# Simulation 284 Terminated Normally. Time: 100.65160632133484
# Simulation 285 Terminated Normally. Time: 102.25159859657288
# Simulation 286 Terminated Normally. Time: 154.73980927467346
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.148541212081909
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.5835843086242676
# Simulation 289 Terminated Normally. Time: 165.57878232002258
# Simulation 290 Terminated Normally. Time: 71.21110892295837
# Simulation 291 Terminated Normally. Time: 102.56692361831665
# Simulation 293 Terminated Normally. Time: 109.70116567611694
# Simulation 294 Terminated Normally. Time: 104.7177186012268
# Simulation 295 Terminated Normally. Time: 103.41700983047485
# Simulation 296 Terminated Normally. Time: 147.63847756385803
# Simulation 297 Terminated Normally. Time: 81.06012225151062
# Simulation 298 Terminated Normally. Time: 91.42776298522949
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.65171217918396
# Simulation 301 Terminated Normally. Time: 145.8112998008728
# Simulation 302 Terminated Normally. Time: 105.26989483833313
# Simulation 303 Terminated Normally. Time: 113.92707014083862
# Simulation 304 Terminated Normally. Time: 80.22972750663757
# Simulation 306 Terminated Normally. Time: 95.48985075950623
# MODFLOW did not terminate normally. Parameters saved to file. Time: 31.65833020210266
# Simulation 308 Terminated Normally. Time: 79.90871214866638
# Simulation 310 Terminated Normally. Time: 89.65864062309265
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.5146071910858154
# MODFLOW did not terminate normally. Parameters saved to file. Time: 67.87779664993286
# Simulation 313 Terminated Normally. Time: 127.42057275772095
# Simulation 315 Terminated Normally. Time: 132.45449304580688
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.418133497238159
# Simulation 318 Terminated Normally. Time: 81.1073591709137
# Simulation 319 Terminated Normally. Time: 100.05562210083008
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.0110676288604736
# MODFLOW did not terminate normally. Parameters saved to file. Time: 17.475934982299805
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.4678421020507812
# MODFLOW did not terminate normally. Parameters saved to file. Time: 12.780948638916016
# Simulation 326 Terminated Normally. Time: 79.23812556266785
# Simulation 327 Terminated Normally. Time: 117.38956952095032
# Simulation 328 Terminated Normally. Time: 148.7291316986084
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.782698392868042
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.4773476123809814
# Simulation 331 Terminated Normally. Time: 106.64952516555786
# MODFLOW did not terminate normally. Parameters saved to file. Time: 71.20631980895996
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.293606996536255
# Simulation 335 Terminated Normally. Time: 79.63755798339844
# Simulation 336 Terminated Normally. Time: 83.04713606834412
# MODFLOW did not terminate normally. Parameters saved to file. Time: 58.35771584510803
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.859469175338745
# Simulation 339 Terminated Normally. Time: 143.6000952720642
# Simulation 340 Terminated Normally. Time: 89.61353135108948
# MODFLOW did not terminate normally. Parameters saved to file. Time: 39.99291157722473
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.5816614627838135
# Simulation 343 Terminated Normally. Time: 102.91406345367432
# Simulation 344 Terminated Normally. Time: 139.53926301002502
# MODFLOW did not terminate normally. Parameters saved to file. Time: 32.24309420585632
# MODFLOW did not terminate normally. Parameters saved to file. Time: 10.63193964958191
# MODFLOW did not terminate normally. Parameters saved to file. Time: 5.421937942504883
# Simulation 350 Terminated Normally. Time: 119.74231767654419
# Simulation 351 Terminated Normally. Time: 81.2105565071106
# Simulation 352 Terminated Normally. Time: 106.50754022598267
# Simulation 353 Terminated Normally. Time: 89.18076753616333
# MODFLOW did not terminate normally. Parameters saved to file. Time: 53.30818438529968
# MODFLOW did not terminate normally. Parameters saved to file. Time: 131.78407740592957
# Simulation 357 Terminated Normally. Time: 87.26042127609253
# Simulation 360 Terminated Normally. Time: 77.21270608901978
# Simulation 362 Terminated Normally. Time: 104.25008082389832
# Simulation 363 Terminated Normally. Time: 121.89172840118408
# Simulation 364 Terminated Normally. Time: 90.86394119262695
# Simulation 365 Terminated Normally. Time: 119.70109415054321
# Simulation 367 Terminated Normally. Time: 94.5702612400055
# Simulation 368 Terminated Normally. Time: 78.87167954444885
# Simulation 369 Terminated Normally. Time: 129.55536913871765
# Simulation 370 Terminated Normally. Time: 139.01839113235474
# MODFLOW did not terminate normally. Parameters saved to file. Time: 48.74418306350708
# Simulation 372 Terminated Normally. Time: 149.1642782688141
# Simulation 373 Terminated Normally. Time: 132.87762594223022
# Simulation 374 Terminated Normally. Time: 82.85273694992065
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.761913537979126
# Simulation 377 Terminated Normally. Time: 96.87192511558533
# MODFLOW did not terminate normally. Parameters saved to file. Time: 13.743832349777222
# Simulation 380 Terminated Normally. Time: 89.65186882019043
# Simulation 381 Terminated Normally. Time: 92.810791015625
# Simulation 382 Terminated Normally. Time: 100.24903345108032
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.720166921615601
# Simulation 384 Terminated Normally. Time: 93.8317940235138
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.979322910308838
# Simulation 386 Terminated Normally. Time: 95.12012696266174
# Simulation 387 Terminated Normally. Time: 72.95097613334656
# Simulation 389 Terminated Normally. Time: 147.95202684402466
# Simulation 391 Terminated Normally. Time: 85.5877332687378
# Simulation 392 Terminated Normally. Time: 129.43813252449036
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.585148572921753
# Simulation 394 Terminated Normally. Time: 90.02674341201782
# Simulation 396 Terminated Normally. Time: 115.26180934906006
# Simulation 397 Terminated Normally. Time: 81.16505241394043
# Simulation 398 Terminated Normally. Time: 79.75205397605896
# MODFLOW did not terminate normally. Parameters saved to file. Time: 68.08577919006348
# Simulation 401 Terminated Normally. Time: 80.07942247390747
# Simulation 402 Terminated Normally. Time: 126.33724427223206
# Simulation 403 Terminated Normally. Time: 111.52198266983032
# MODFLOW did not terminate normally. Parameters saved to file. Time: 35.72520637512207
# Simulation 406 Terminated Normally. Time: 110.55124807357788
# Simulation 407 Terminated Normally. Time: 149.37188625335693
# Simulation 410 Terminated Normally. Time: 88.8051528930664
# Simulation 411 Terminated Normally. Time: 88.07954668998718
# MODFLOW did not terminate normally. Parameters saved to file. Time: 53.50284171104431
# Simulation 413 Terminated Normally. Time: 86.30320048332214
# Simulation 414 Terminated Normally. Time: 139.66089415550232
# Simulation 415 Terminated Normally. Time: 155.39805817604065
# MODFLOW did not terminate normally. Parameters saved to file. Time: 48.95250105857849
# Simulation 418 Terminated Normally. Time: 95.02754092216492
# MODFLOW did not terminate normally. Parameters saved to file. Time: 51.82885026931763
# Simulation 420 Terminated Normally. Time: 124.03416728973389
# Simulation 421 Terminated Normally. Time: 82.92585730552673
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.4094297885894775
# MODFLOW did not terminate normally. Parameters saved to file. Time: 24.109042644500732
# Simulation 425 Terminated Normally. Time: 113.90552806854248
# Simulation 426 Terminated Normally. Time: 148.63617753982544
# Simulation 427 Terminated Normally. Time: 83.30645990371704
# Simulation 428 Terminated Normally. Time: 160.13696599006653
# Simulation 429 Terminated Normally. Time: 75.61105227470398
# MODFLOW did not terminate normally. Parameters saved to file. Time: 70.36855864524841
# Simulation 431 Terminated Normally. Time: 87.64414405822754
# Simulation 432 Terminated Normally. Time: 86.18154978752136
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.864431381225586
# Simulation 435 Terminated Normally. Time: 99.58816051483154
# Simulation 436 Terminated Normally. Time: 127.42815279960632
# Simulation 437 Terminated Normally. Time: 89.66153693199158
# MODFLOW did not terminate normally. Parameters saved to file. Time: 93.21038460731506
# Simulation 439 Terminated Normally. Time: 90.32369065284729
# Simulation 440 Terminated Normally. Time: 87.22323560714722
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.206139087677002
# Simulation 442 Terminated Normally. Time: 115.82679772377014
# Simulation 443 Terminated Normally. Time: 88.52695655822754
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.693509578704834
# Simulation 446 Terminated Normally. Time: 155.182879447937
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.8002002239227295
# Simulation 449 Terminated Normally. Time: 101.37160730361938
# Simulation 450 Terminated Normally. Time: 95.29716348648071
# Simulation 451 Terminated Normally. Time: 73.740647315979
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.9149973392486572
# Simulation 453 Terminated Normally. Time: 92.6521646976471
# Simulation 454 Terminated Normally. Time: 72.78688549995422
# Simulation 456 Terminated Normally. Time: 79.66329407691956
# Simulation 458 Terminated Normally. Time: 101.67973208427429
# Simulation 459 Terminated Normally. Time: 122.00657057762146
# Simulation 460 Terminated Normally. Time: 86.6428279876709
# Simulation 462 Terminated Normally. Time: 106.5527126789093
# Simulation 463 Terminated Normally. Time: 89.64719676971436
# MODFLOW did not terminate normally. Parameters saved to file. Time: 8.540534734725952
# Simulation 465 Terminated Normally. Time: 147.11597776412964
# Simulation 466 Terminated Normally. Time: 77.40497255325317
# Simulation 467 Terminated Normally. Time: 108.04399490356445
# MODFLOW did not terminate normally. Parameters saved to file. Time: 94.29314041137695
# Simulation 469 Terminated Normally. Time: 96.355388879776
# Simulation 470 Terminated Normally. Time: 92.45755696296692
# Simulation 471 Terminated Normally. Time: 118.69380497932434
# Simulation 472 Terminated Normally. Time: 104.92216658592224
# Simulation 473 Terminated Normally. Time: 101.46288299560547
# Simulation 475 Terminated Normally. Time: 133.60601329803467
# Simulation 476 Terminated Normally. Time: 86.64725065231323
# Simulation 477 Terminated Normally. Time: 93.06691670417786
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.698310613632202
# Simulation 479 Terminated Normally. Time: 86.31507611274719
# Simulation 480 Terminated Normally. Time: 134.01389956474304
# Simulation 481 Terminated Normally. Time: 116.598073720932
# Simulation 483 Terminated Normally. Time: 167.8702208995819
# Simulation 484 Terminated Normally. Time: 144.36840987205505
# Simulation 485 Terminated Normally. Time: 133.38594126701355
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.2705492973327637
# MODFLOW did not terminate normally. Parameters saved to file. Time: 5.6698689460754395
# MODFLOW did not terminate normally. Parameters saved to file. Time: 9.512302875518799
# Simulation 489 Terminated Normally. Time: 107.94064402580261
# Simulation 490 Terminated Normally. Time: 88.57391786575317
# Simulation 492 Terminated Normally. Time: 99.78813576698303
# Simulation 493 Terminated Normally. Time: 118.8353796005249
# Simulation 494 Terminated Normally. Time: 107.91355776786804
# Simulation 495 Terminated Normally. Time: 82.76748299598694
# MODFLOW did not terminate normally. Parameters saved to file. Time: 23.62973928451538
# MODFLOW did not terminate normally. Parameters saved to file. Time: 86.39412641525269
# MODFLOW did not terminate normally. Parameters saved to file. Time: 108.6462471485138
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.542649984359741
# MODFLOW did not terminate normally. Parameters saved to file. Time: 70.15224957466125
# Simulation 502 Terminated Normally. Time: 79.64861798286438
# Simulation 503 Terminated Normally. Time: 107.20083212852478
# Simulation 504 Terminated Normally. Time: 127.16922044754028
# Simulation 505 Terminated Normally. Time: 81.81732773780823
# Simulation 506 Terminated Normally. Time: 109.61567711830139
# MODFLOW did not terminate normally. Parameters saved to file. Time: 36.668779373168945
# Simulation 508 Terminated Normally. Time: 89.9407000541687
# Simulation 509 Terminated Normally. Time: 117.38691425323486
# Simulation 511 Terminated Normally. Time: 99.94639372825623
# Simulation 512 Terminated Normally. Time: 134.00040817260742
# Simulation 513 Terminated Normally. Time: 91.88440203666687
# Simulation 515 Terminated Normally. Time: 126.875244140625
# Simulation 517 Terminated Normally. Time: 117.03974986076355
# Simulation 518 Terminated Normally. Time: 86.80718445777893
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.5607266426086426
# Simulation 521 Terminated Normally. Time: 104.01938319206238
# Simulation 522 Terminated Normally. Time: 112.91497421264648
# MODFLOW did not terminate normally. Parameters saved to file. Time: 131.3212115764618
# MODFLOW did not terminate normally. Parameters saved to file. Time: 77.09204030036926
# Simulation 531 Terminated Normally. Time: 116.9114248752594
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.5665040016174316
# Simulation 533 Terminated Normally. Time: 161.46250081062317
# MODFLOW did not terminate normally. Parameters saved to file. Time: 32.12927269935608
# Simulation 536 Terminated Normally. Time: 71.31280279159546
# Simulation 537 Terminated Normally. Time: 127.51015949249268
# Simulation 539 Terminated Normally. Time: 147.33533000946045
# Simulation 540 Terminated Normally. Time: 84.81821417808533
# Simulation 541 Terminated Normally. Time: 79.81677556037903
# MODFLOW did not terminate normally. Parameters saved to file. Time: 71.48644685745239
# Simulation 543 Terminated Normally. Time: 74.01505851745605
# MODFLOW did not terminate normally. Parameters saved to file. Time: 19.275030374526978
# Simulation 545 Terminated Normally. Time: 75.47535037994385
# Simulation 546 Terminated Normally. Time: 126.8075602054596
# Simulation 547 Terminated Normally. Time: 82.82716178894043
# Simulation 548 Terminated Normally. Time: 77.57656383514404
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.7159950733184814
# Simulation 550 Terminated Normally. Time: 143.16535139083862
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.467726707458496
# Simulation 553 Terminated Normally. Time: 110.22216010093689
# Simulation 554 Terminated Normally. Time: 125.00743770599365
# Simulation 555 Terminated Normally. Time: 139.70862293243408
# Simulation 556 Terminated Normally. Time: 105.88403654098511
# Simulation 557 Terminated Normally. Time: 148.39813113212585
# MODFLOW did not terminate normally. Parameters saved to file. Time: 38.55709266662598
# Simulation 562 Terminated Normally. Time: 102.32797479629517
# Simulation 564 Terminated Normally. Time: 85.93685913085938
# MODFLOW did not terminate normally. Parameters saved to file. Time: 46.7219123840332
# MODFLOW did not terminate normally. Parameters saved to file. Time: 15.083918571472168
# Simulation 567 Terminated Normally. Time: 95.58777189254761
# MODFLOW did not terminate normally. Parameters saved to file. Time: 87.46983122825623
# Simulation 569 Terminated Normally. Time: 92.48430013656616
# Simulation 570 Terminated Normally. Time: 102.14508700370789
# Simulation 571 Terminated Normally. Time: 82.25628161430359
# Simulation 572 Terminated Normally. Time: 90.97924971580505
# Simulation 573 Terminated Normally. Time: 82.49408507347107
# Simulation 574 Terminated Normally. Time: 78.93533968925476
# Simulation 575 Terminated Normally. Time: 138.46297454833984
# Simulation 576 Terminated Normally. Time: 78.54517078399658
# Simulation 577 Terminated Normally. Time: 90.542964220047
# Simulation 578 Terminated Normally. Time: 86.84088039398193
# Simulation 579 Terminated Normally. Time: 108.56908702850342
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.228978157043457
# Simulation 581 Terminated Normally. Time: 95.7881691455841
# Simulation 582 Terminated Normally. Time: 136.43785095214844
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.2661120891571045
# Simulation 585 Terminated Normally. Time: 100.52920460700989
# MODFLOW did not terminate normally. Parameters saved to file. Time: 102.39733481407166
# MODFLOW did not terminate normally. Parameters saved to file. Time: 32.62329626083374
# MODFLOW did not terminate normally. Parameters saved to file. Time: 94.82938599586487
# Simulation 590 Terminated Normally. Time: 142.12202143669128
# Simulation 591 Terminated Normally. Time: 131.79861545562744
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.298677682876587
# MODFLOW did not terminate normally. Parameters saved to file. Time: 130.36524415016174
# Simulation 594 Terminated Normally. Time: 84.37965750694275
# Simulation 595 Terminated Normally. Time: 136.22711992263794
# Simulation 596 Terminated Normally. Time: 89.88923120498657
# Simulation 597 Terminated Normally. Time: 152.70659255981445
# Simulation 599 Terminated Normally. Time: 99.56951141357422
# Simulation 600 Terminated Normally. Time: 91.46360373497009
# MODFLOW did not terminate normally. Parameters saved to file. Time: 25.25683283805847
# Simulation 606 Terminated Normally. Time: 93.88271689414978
# MODFLOW did not terminate normally. Parameters saved to file. Time: 43.480546712875366
# MODFLOW did not terminate normally. Parameters saved to file. Time: 25.389877796173096
# MODFLOW did not terminate normally. Parameters saved to file. Time: 16.798120260238647
# Simulation 612 Terminated Normally. Time: 106.20203256607056
# Simulation 613 Terminated Normally. Time: 129.10503602027893
# MODFLOW did not terminate normally. Parameters saved to file. Time: 90.05294036865234
# Simulation 615 Terminated Normally. Time: 98.7125973701477
# MODFLOW did not terminate normally. Parameters saved to file. Time: 18.790405988693237
# Simulation 617 Terminated Normally. Time: 95.43604636192322
# Simulation 618 Terminated Normally. Time: 106.7329523563385
# Simulation 619 Terminated Normally. Time: 104.93084383010864
# Simulation 621 Terminated Normally. Time: 146.91603565216064
# MODFLOW did not terminate normally. Parameters saved to file. Time: 92.92164850234985
# MODFLOW did not terminate normally. Parameters saved to file. Time: 25.898940563201904
# Simulation 625 Terminated Normally. Time: 147.39014792442322
# Simulation 626 Terminated Normally. Time: 115.01481795310974
# Simulation 627 Terminated Normally. Time: 87.21230411529541
# Simulation 628 Terminated Normally. Time: 84.16225910186768
# Simulation 629 Terminated Normally. Time: 123.8803403377533
# Simulation 630 Terminated Normally. Time: 104.19781351089478
# Simulation 631 Terminated Normally. Time: 100.29843974113464
# Simulation 632 Terminated Normally. Time: 99.49033188819885
# Simulation 633 Terminated Normally. Time: 81.10234189033508
# Simulation 634 Terminated Normally. Time: 82.4770576953888
# Simulation 635 Terminated Normally. Time: 153.99735569953918
# MODFLOW did not terminate normally. Parameters saved to file. Time: 26.33529782295227
# Simulation 637 Terminated Normally. Time: 79.8553078174591
# Simulation 638 Terminated Normally. Time: 87.27596139907837
# Simulation 639 Terminated Normally. Time: 95.31276345252991
# Simulation 640 Terminated Normally. Time: 93.58133029937744
# Simulation 641 Terminated Normally. Time: 93.05912041664124
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.7903332710266113
# MODFLOW did not terminate normally. Parameters saved to file. Time: 21.75779938697815
# Simulation 644 Terminated Normally. Time: 102.94478273391724
# Simulation 645 Terminated Normally. Time: 131.9997947216034
# Simulation 646 Terminated Normally. Time: 110.36855983734131
# Simulation 648 Terminated Normally. Time: 82.62507557868958
# MODFLOW did not terminate normally. Parameters saved to file. Time: 54.46514964103699
# Simulation 652 Terminated Normally. Time: 85.33747267723083
# MODFLOW did not terminate normally. Parameters saved to file. Time: 99.09275341033936
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.9857664108276367
# Simulation 658 Terminated Normally. Time: 107.90776705741882
# Simulation 659 Terminated Normally. Time: 114.31241846084595
# MODFLOW did not terminate normally. Parameters saved to file. Time: 105.37067604064941
# Simulation 661 Terminated Normally. Time: 84.77984523773193
# Simulation 662 Terminated Normally. Time: 143.77955627441406
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.8938379287719727
# Simulation 664 Terminated Normally. Time: 90.6540150642395
# Simulation 665 Terminated Normally. Time: 69.99927926063538
# Simulation 669 Terminated Normally. Time: 149.0283808708191
# MODFLOW did not terminate normally. Parameters saved to file. Time: 87.38533544540405
# Simulation 671 Terminated Normally. Time: 145.30497789382935
# Simulation 673 Terminated Normally. Time: 75.66075158119202
# MODFLOW did not terminate normally. Parameters saved to file. Time: 48.761162519454956
# Simulation 676 Terminated Normally. Time: 90.13560509681702
# Simulation 677 Terminated Normally. Time: 150.18428134918213
# Simulation 678 Terminated Normally. Time: 101.02151083946228
# Simulation 679 Terminated Normally. Time: 84.40346074104309
# Simulation 682 Terminated Normally. Time: 112.55462789535522
# Simulation 683 Terminated Normally. Time: 160.617684841156
# Simulation 684 Terminated Normally. Time: 147.11631035804749
# Simulation 685 Terminated Normally. Time: 82.71291637420654
# Simulation 686 Terminated Normally. Time: 96.2370057106018
# Simulation 687 Terminated Normally. Time: 150.71143865585327
# MODFLOW did not terminate normally. Parameters saved to file. Time: 27.518940210342407
# MODFLOW did not terminate normally. Parameters saved to file. Time: 51.590691566467285
# MODFLOW did not terminate normally. Parameters saved to file. Time: 24.12460970878601
# Simulation 691 Terminated Normally. Time: 93.60450053215027
# Simulation 693 Terminated Normally. Time: 87.85314321517944
# Simulation 694 Terminated Normally. Time: 82.87605023384094
# Simulation 695 Terminated Normally. Time: 147.0613877773285
# Simulation 697 Terminated Normally. Time: 83.24270915985107
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.991412878036499
# MODFLOW did not terminate normally. Parameters saved to file. Time: 3.082111120223999
# MODFLOW did not terminate normally. Parameters saved to file. Time: 5.45343017578125
# Simulation 701 Terminated Normally. Time: 139.5420126914978
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.4720630645751953
# Simulation 703 Terminated Normally. Time: 97.26355147361755
# Simulation 705 Terminated Normally. Time: 121.01404738426208
# Simulation 706 Terminated Normally. Time: 95.34811639785767
# Simulation 707 Terminated Normally. Time: 163.3738808631897
# Simulation 708 Terminated Normally. Time: 103.55605602264404
# Simulation 709 Terminated Normally. Time: 83.92578864097595
# Simulation 710 Terminated Normally. Time: 89.55042457580566
# Simulation 711 Terminated Normally. Time: 137.0935299396515
# MODFLOW did not terminate normally. Parameters saved to file. Time: 71.3082914352417
# Simulation 714 Terminated Normally. Time: 143.4582600593567
# Simulation 715 Terminated Normally. Time: 102.61276245117188
# Simulation 716 Terminated Normally. Time: 104.71916365623474
# Simulation 718 Terminated Normally. Time: 130.71406173706055
# Simulation 719 Terminated Normally. Time: 115.30999755859375
# Simulation 720 Terminated Normally. Time: 105.7132921218872
# MODFLOW did not terminate normally. Parameters saved to file. Time: 20.50516653060913
# MODFLOW did not terminate normally. Parameters saved to file. Time: 2.33007550239563
# MODFLOW did not terminate normally. Parameters saved to file. Time: 117.38644933700562
# Simulation 725 Terminated Normally. Time: 79.5206356048584
# Simulation 726 Terminated Normally. Time: 139.0134687423706
# Simulation 727 Terminated Normally. Time: 120.09401679039001
# Simulation 729 Terminated Normally. Time: 81.02961802482605
# Simulation 730 Terminated Normally. Time: 90.86083984375
# Simulation 731 Terminated Normally. Time: 85.0578932762146
# Simulation 734 Terminated Normally. Time: 90.87258696556091
# Simulation 735 Terminated Normally. Time: 146.20621585845947
# MODFLOW did not terminate normally. Parameters saved to file. Time: 4.641650676727295
# Simulation 737 Terminated Normally. Time: 95.45108246803284
# Simulation 739 Terminated Normally. Time: 83.08501410484314
# Simulation 740 Terminated Normally. Time: 91.94109916687012
# Simulation 741 Terminated Normally. Time: 75.22883415222168
# Simulation 742 Terminated Normally. Time: 97.35455441474915
# Simulation 743 Terminated Normally. Time: 139.0893898010254
# Simulation 744 Terminated Normally. Time: 90.10079288482666
# Simulation 745 Terminated Normally. Time: 69.10592460632324
# MODFLOW did not terminate normally. Parameters saved to file. Time: 49.53910040855408
# Simulation 748 Terminated Normally. Time: 92.08748173713684
# Simulation 749 Terminated Normally. Time: 82.11861944198608
# 175  simulations did not terminate normally.

# %% [markdown]
# ## Looking at the SFR Output

# %%
#print(sfr.reach_data)
#print(error_list)


modelname = "ScenarioSfr750SeasonsTest_"+str(1)
sfrout = SfrFile(modws+'/'+modelname+'.sfr.out')
df = sfrout.get_dataframe()
df.reset_index(drop = True, inplace = True) #FOr some reason the index seems to be off number wise so this helps


# Trying to figure out why the kstp and kper are all 0s - could just back the info out from the index number though
#times = sfrout.get_times() 
#df['kstpkper'] = times

#Backing out the stress period from the rows
#should be 50 rows for the first stress period (1 timestep for each reach), then 1500 (50*30) for the remaining 20 stressperiods for a total of 30050 timesteps (rows)
df['Stp']= 1
df.iloc[50:,-1] = (np.divmod(np.arange(len(df)-50),50*30*2)[0]+1)+1

print(df[df['Stp'] == 2])
# Out:
#       layer  row  column  segment  reach       Qin  Qaquifer      Qout  Qovr  \
# 50        1   26       1        1      1    1.0000    0.0000    1.0000   0.0
# 51        1   26       2        1      2    1.0000   -5.1020    6.1358   0.0
# 52        1   26       3        1      3    6.1358   -5.5936   11.7850   0.0
# 53        1   26       4        1      4   11.7850   -6.1487   17.9850   0.0
# 54        1   26       5        1      5   17.9850   -6.6983   24.7510   0.0
# ...     ...  ...     ...      ...    ...       ...       ...       ...   ...
# 3045      1   26      46        1     46  156.2500   10.2500  146.5100   0.0
# 3046      1   26      47        1     47  146.5100   13.3000  133.7200   0.0
# 3047      1   26      48        1     48  133.7200   17.8940  116.3300   0.0
# 3048      1   26      49        1     49  116.3300   25.4560   91.3690   0.0
# 3049      1   26      50        1     50   91.3690    0.0000   91.8390   0.0
#
#       Qprecip  ...    stage   depth  width    Cond  gradient  kstpkper  k   i  \
# 50        0.0  ...  95.3469  0.6119   1.09  0.0000    0.0000    (0, 0)  0  25
# 51        0.0  ...  95.3993  1.1940   1.27  0.7124   -3.5810    (0, 0)  0  25
# 52        0.0  ...  95.5924  1.9180   1.45  0.8134   -3.4380    (0, 0)  0  25
# 53        0.0  ...  95.5710  2.4270   1.63  0.9144   -3.3620    (0, 0)  0  25
# 54        0.0  ...  95.4456  2.8310   1.81  1.0150   -3.2990    (0, 0)  0  25
# ...       ...  ...      ...     ...    ...     ...       ...       ... ..  ..
# 3045      0.0  ...  74.2805  3.4580   9.19  5.1550    0.9941    (0, 0)  0  25
# 3046      0.0  ...  73.5322  3.2620   9.37  5.2560    1.2650    (0, 0)  0  25
# 3047      0.0  ...  72.7144  3.0120   9.55  5.3570    1.6700    (0, 0)  0  25
# 3048      0.0  ...  71.7669  2.6640   9.73  5.4580    2.3320    (0, 0)  0  25
# 3049      0.0  ...  71.2173  2.4430   9.91  0.0000    0.0000    (0, 0)  0  25
#
#        j  Stp
# 50     0    2
# 51     1    2
# 52     2    2
# 53     3    2
# 54     4    2
# ...   ..  ...
# 3045  45    2
# 3046  46    2
# 3047  47    2
# 3048  48    2
# 3049  49    2
#
# [3000 rows x 21 columns]

# %%
#Plotting out stream Q with head values across all time stepss
#modelname = "ScenarioSfr2500_Trans_1"
n = np.loadtxt('TransSamples.txt').astype('int')
n = [0,1]
modelname = "ScenarioSfr750SeasonsTest_"+str(n[1])
sfrout = SfrFile(modws+'/'+modelname+'.sfr.out')
df = sfrout.get_dataframe()
df.reset_index(drop = False, inplace = True) #FOr some reason the index seems to be off number wise so this helps


# Trying to figure out why the kstp and kper are all 0s - could just back the info out from the index number though
#times = sfrout.get_times() 
#df['kstpkper'] = times

#Backing out the stress period from the rows
#should be 50 rows for the first stress period (1 timestep for each reach), then 1500 (50*30) for the remaining 20 stressperiods for a total of 30050 timesteps (rows)
df['Stp']= 1
df.iloc[50:,-1] = (np.divmod(np.arange(len(df)-50),50*30*2)[0]+1)+1 #Stp is the last col (-1) so the iloc references every row beyond 50 in the last column
#added *2 above for each computation step with kinematic wave routing

#group rows by change in Stp and grab the last Stress period 
Stpdf = df.groupby('Stp').tail(n=50) #groups tthe dataframe by the Stress period then grabs the last 50 rows (reaches) of the stress period representing the last timestep
#print(Stpdf.iloc[50])
#print(df.iloc[50])

inds = df.reach == 32 #grab indices for reach of interest
#print(df.reach[inds].astype(str))

ax = df.loc[inds, ["Qin","Qout"]].plot(figsize = (20,7))
ax.set_ylabel("Flow, in cubic feet per second")
ax.set_xlabel("Time step");

#Add the Stressperiod dataframe to the plot (checking to make sure it's all correct) - we lose the nice curves but this is much less data
#Stpdf.loc[inds, ["Qout", "Qin"]].plot(figsize = (20,7), ax = ax)


#modelname = "ScenarioSfr750Seasons_"+str(i)
headobj = flopy.utils.binaryfile.HeadFile(modws+'/'+modelname+'.hds')
#head = headobj.get_alldata(nodata=-9.9998999e+02)
head = headobj.get_ts([(0,20,32)]) #time series from obs well inbetween stream and pumping well
head[:,0] = (head[:,0] / 6) * 50 *2 #go from total time to the reach (50) period (6) times in the SFR file #*2 if routing is on
#print(head)
ax2 = ax.twinx()
ax2.plot(head[:,0],head[:,1], label ='Well', color='k')
ax2.set_ylabel('Head (m)')
ax2.legend()

#print(df.loc[inds,["Qin","Qaquifer","Qout","Stp"]][df.Stp > 9])
Stpdf.reset_index(drop=True, inplace = True)
#print(Stpdf)

# %%
#Look at the variation in Q aquifer for the 5 random sampled simulations

for i in n3[:10]:
    modelname = "ScenarioSfr750SeasonsTest_"+str(i)
    sfrout = SfrFile(modws+'/'+modelname+'.sfr.out')
    df = sfrout.get_dataframe()
    df.reset_index(drop = True, inplace = True)
     #grab indices for reach of interest
#print(df.reach[inds].astype(str))
    inds = df.reach == 32
    if i == n3[0]:
        ax = df.loc[inds, ["Qaquifer"]].plot(figsize = (20,7))
    else:
        df.loc[inds, ["Qaquifer"]].plot(figsize = (20,7), ax =ax)
    
ax.set_ylabel("Flow, in cubic feet per second")
ax.set_xlabel("Time step");
# Out:
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles
# C:\Users\davem\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:609: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = leg.legendHandles

# %%
col_names = ['K', 'Low_K_ratio', 'Sy', 'Rech', 'ET_valley', 'ET_rip_ratio', 'Stream_K_ratio']
pd.DataFrame(sampling[n[:5]], columns = col_names).head(5)
# Out:
#           K  Low_K_ratio        Sy      Rech  ET_valley  ET_rip_ratio  \
# 0  0.034612     0.001155  0.151135  0.000022   0.000004      4.223459
# 1  0.075289     0.000542  0.237767  0.000046   0.000005      6.191098
# 2  0.022627     0.011371  0.204247  0.000024   0.000005      6.489352
# 3  0.046207     0.000217  0.472853  0.000039   0.000002      7.601402
# 4  0.018518     0.000373  0.433478  0.000039   0.000002      6.391771
#
#    Stream_K_ratio
# 0        0.001448
# 1        0.000529
# 2        0.004659
# 3        0.000132
# 4        0.005211

# %%
#modelname = "ScenarioSfr750Seasons_"+str(i)
headobj = flopy.utils.binaryfile.HeadFile(modws+'/'+modelname+'.hds')
#head = headobj.get_alldata(nodata=-9.9998999e+02)
head = headobj.get_ts([(0,21,32)])
print(head)
head[:,0] = (head[:,0] / 6) * 50 #go from total time to the reach (50) period (6) times in the SFR file

plt.figure(figsize = (20,7))
plt.plot(head[:,0],head[:,1])

# %% [markdown]
# ## Saving the output for each run

# %%
#get rid of the simulations that return an error and save the outputs

#first get the simulations from teh Steady Pump (drawdown) runs - re doing this from above as I overwrote n2
error_list_SP = np.loadtxt('ErrorSteadyPump_Sfr750Test.txt')
sampling = np.loadtxt("ModflowParams7-750Test12.txt")
n = np.arange(0,len(sampling))
n2 = np.setdiff1d(n, error_list_SP[:,0].astype('int'))

#Now get the most recent error list and remove those from n2
error_list_seasons = np.loadtxt("ErrorSeasons_Sfr750Test.txt")
#eidx = np.array(error_list)[:,0].astype(int)
n3 = np.setdiff1d(n2, error_list_seasons[:,0].astype('int'))

for k,i in enumerate(n3):
    modelname = "ScenarioSfr750SeasonsTest_"+str(i)
    sfrout = SfrFile(modws+'/'+modelname+'.sfr.out')
    df = sfrout.get_dataframe()
    #should be 50 rows for the first stress period (1 timestep for each reach), then 1500 (50*30) for the remaining 20 stressperiods for a total of 30050 timesteps (rows)
    df['Stp']= 1
    df.iloc[50:,-1] = (np.divmod(np.arange(len(df)-50),50*30*2)[0]+1)+1 #Stp is the last col (-1) so the iloc references every row beyond 50 in the last column
    df['simnum'] = i
    #group rows by change in Stp and grab the last Stress period 
    Stpdf = df.groupby('Stp').tail(n=50) #groups tthe dataframe by the Stress period then grabs the last 50 rows (reaches) of the stress period representing the last timestep
    Stpdf.reset_index(drop=True, inplace = True)
    if k == 0:
        savedf = Stpdf
    else:
        savedf = savedf.append(Stpdf) #apparently appending a dataframe is improper so this takes a minute

print(len(savedf))
savedf.to_csv('TransSeasonsOutputStpTest.csv')
# Out:
# 861000

# %%
#Test 
newdf = pd.read_csv('TransSeasonsOutputStpTest.csv')
print(len(newdf.simnum.unique()))
# Out:
# 420
