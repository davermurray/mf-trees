# %%
import numpy as np
import flopy
import matplotlib.pyplot as plt
import matplotlib as mp
import pandas as pd
import numpy as np
import os
import csv

import pandas as pd

# %%
error_list = np.loadtxt('ErrorSS_Riv.txt')

# %%
print(error_list)

for i in range(1,8):
    plt.plot(error_list[:,i])
    plt.show()
# Out:
# [[9.00000000e+00 3.41630539e+00 6.06764832e-01 5.33637560e-02
#   4.46196903e-05 9.28949756e-05 2.17721724e+00 4.57154398e-04]
#  [1.00000000e+01 4.36658318e+00 3.62489177e-01 1.12696347e-01
#   4.49431959e-05 8.13553993e-05 2.90951661e+00 5.26619519e-04]
#  [2.10000000e+01 3.76354032e+00 9.68480567e-01 1.69454048e-01
#   4.57949594e-05 8.35933620e-05 2.45226207e+00 7.56477867e-04]
#  [2.30000000e+01 2.79453022e+00 9.09582458e-01 2.73520047e-01
#   4.34036264e-05 9.58457808e-05 2.28063025e+00 5.70247937e-04]]
